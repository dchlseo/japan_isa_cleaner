# %%
import pandas as pd

# %%
data_dir_kor = "../data/cleaned/japan_isa_nationality_by_airport_200601-202605_korean/japan_isa_nationality_by_airport_200601-202605_korean_long.csv"
data_dir_eng = "../data/cleaned/japan_isa_nationality_by_airport_200601-202605_english/japan_isa_nationality_by_airport_200601-202605_english_long.csv"

df_kor = pd.read_csv(data_dir_kor)
df_eng = pd.read_csv(data_dir_eng)

df_kor.shape, df_eng.shape
# Out:
# ((2348416, 5), (2385110, 5))

# %%
df_kor["Country"].unique(), df_kor["Country"].nunique()
# Out:
# (array([nan, '총계', '아시아', '아프가니스탄', '아랍에미리트', '미얀마', '바레인', '부탄', '방글라데시',
#         '브루나이', '캄보디아', '스리랑카', '중국', '대만', '홍콩', '기타 중국 지역', '키프로스',
#         '동티모르', '인도', '인도네시아', '이란', '이라크', '이스라엘', '요르단', '한국', '북한',
#         '쿠웨이트', '라오스', '레바논', '말레이시아', '몽골', '오만', '몰디브', '네팔', '파키스탄',
#         '필리핀', '카타르', '사우디아라비아', '시리아', '싱가포르', '태국', '튀르키예', '베트남', '예멘',
#         '팔레스타인', '유럽', '영국', '남아프리카공화국', '캐나다', '멕시코', '미국', '아르헨티나',
#         '브라질', '호주', '뉴질랜드', '무국적'], dtype=object),
#  55)

# %%
df_eng["Country"].unique(), df_eng["Country"].nunique()
# Out:
# (array([nan, 'Total', 'Asia', 'Afghanistan', 'United Arab Emirates',
#         'Myanmar', 'Bahrain', 'Bhutan', 'Bangladesh', 'Brunei', 'Cambodia',
#         'Sri Lanka', 'China', 'Taiwan', 'Hong Kong (China)',
#         'Other China Regions', 'Cyprus', 'East Timor', 'India',
#         'Indonesia', 'Iran', 'Iraq', 'Israel', 'Jordan', 'South Korea',
#         'North Korea', 'Kuwait', 'Laos', 'Lebanon', 'Malaysia', 'Mongolia',
#         'Oman', 'Maldives', 'Nepal', 'Pakistan', 'Philippines', 'Qatar',
#         'Saudi Arabia', 'Syria', 'Singapore', 'Thailand', 'Türkiye',
#         'Vietnam', 'Yemen', 'Palestine', 'Europe', 'United Kingdom',
#         'South Africa', 'Canada', 'Mexico', 'United States', 'Argentina',
#         'Brazil', 'Australia', 'New Zealand', 'Stateless'], dtype=object),
#  55)
